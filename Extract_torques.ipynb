# %%
import gzip
import shutil
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = r'C:\Program Files\DigiMove\DigiMove\Projet_Mottet\force_time_extended.tsv.gz'

# %%
#Extract .gz file
with gzip.open(file_path, 'rb') as f_in:
    with open('file', 'wb') as f_out:
       shutil.copyfileobj(f_in, f_out)

# %%
#load the tsv file that was extracted
df = pd.read_csv('file', sep='\t')
#display the first 5 rows of the dataframe
df.head()
# Out:
#     time_s    force_N  angle_deg  velocity_deg_s  torque_Nm
# 0  0.00000  50.859508  34.017481      128.275856  42.155764
# 1  0.01001  49.625968  35.301523        2.756371  40.500856
# 2  0.02002  49.275426  34.072663       -5.759629  40.816201
# 3  0.03003  53.353486  35.186215        2.443264  43.604927
# 4  0.04004  54.339099  34.121577      -33.613880  44.984577

# %%
#visualize the data
plt.plot(df['time_s'], df['torque_Nm'])
plt.xlabel('Time (s)')
plt.ylabel('Torque (Nm)')
plt.title('Torque vs Time')
plt.grid()
plt.show()

# %%
#detect events, prendre le plus gros pic après 1 min sans activité
